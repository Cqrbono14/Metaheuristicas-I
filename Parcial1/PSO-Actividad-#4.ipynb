# %% [markdown]
# # Universidad Autónoma de Aguascalientes
# # Departamento: Ciencias de la Computación
# # Materia: Metaheurísticas I
# # Profesor: Dr. Francisco Javier Luna Rosas
# # Alumno: Haniel Joab Cruz Chávez
# #### Semestre: Agosto-Diciembre 2025

# %% [markdown]
# ## Actividad No. 4. Optimización por enjambre de partículas (PSO, por sus siglas en inglés, Particle Swarm Optimization)

# %% [markdown]
# ### PSO es un algoritmo de optimización basado en la simulación de la conducta social de organismos, como bandadas de aves o bancos de peces. En esta practica implementaremos PSO para buscar el optimo global de una función en 2D y la graficamos: (f(x) = -(1 - ((11/2) * x - 7/2)**2) * (cos((11/2)* x - 7/2) + 1) + 2).

# %% [markdown]
# ## Paso 1: Importar las librerías necesarias

# %%
import numpy as np
import matplotlib.pyplot as plt
import random

# %% [markdown]
# ## Paso 2: Definir la función objetivo

# %%
# Definir la función objetivo
def objective_function(x):
    return -(1 - ((11/2) * x - 7/2)**2) * (np.cos((11/2)* x - 7/2) + 1) + 2

# %% [markdown]
# ## Paso 3: Inicializar los parámetros del PSO

# %%
# Parámetros PSO
num_particles = 30
num_dimensions = 1
num_iterations = 100
w = 0.5  # Factor de inercia que controla la velocidad
c1 = 1.5  # Coeficiente cognitivo
c2 = 2.0  # Coeficiente social

# Limites de la búsqueda
bounds = (-10, 10)

history_positions = []

# %% [markdown]
# ## Paso 4: Inicializamos las particulas y velocidades

# %%
# Inicializar las partículas
particles = np.random.uniform(bounds[0], bounds[1], (num_particles, num_dimensions))
velocities = np.random.uniform(-1, 1, (num_particles, num_dimensions))

# Inicializar las mejores posiciones individuales y globales
p_best_position = particles.copy()
p_best_value = np.array([objective_function(x) for x in particles])
g_best_position = p_best_position[np.argmin(p_best_value)] #minimo valor de xi
g_best_value = np.min(p_best_value) #valor de la funcion para la mejor xi

for t in range(num_iterations):
    for i in range(num_particles):
        # Evaluar la función objetivo
        fitness = objective_function(particles[i])

        # Actualizar la mejor posición individual
        if fitness < p_best_value[i]:
            p_best_value[i] = fitness
            p_best_position[i] = particles[i].copy()

        # Actualizar la mejor posición global
        if fitness < g_best_value:
            g_best_value = fitness
            g_best_position = particles[i].copy()

    # Actualizar velocidades y posiciones
    for i in range(num_particles):
        r1 = random.random()
        r2 = random.random()

        velocities[i] = (w * velocities[i]
                         + c1 * r1 * (p_best_position[i] - particles[i])
                         + c2 * r2 * (g_best_position - particles[i]))

        particles[i] = particles[i] + velocities[i]

        # Respetar los límites de la búsqueda
        particles[i] = np.clip(particles[i], bounds[0], bounds[1])

    history_positions.append(particles.copy()) #Para graficar

    print(f"Iteración {t+1}/{num_iterations}, Mejor valor global: {g_best_value}")

print(f"Mejor posición encontrada: {g_best_position}, con valor: {g_best_value}")
# Out:
# Iteración 1/100, Mejor valor global: 2.02855485147874
# Iteración 2/100, Mejor valor global: [0.25720955]
# Iteración 3/100, Mejor valor global: [0.00218403]
# Iteración 4/100, Mejor valor global: [0.00218403]
# Iteración 5/100, Mejor valor global: [0.00218403]
# Iteración 6/100, Mejor valor global: [0.00218403]
# Iteración 7/100, Mejor valor global: [0.00218403]
# Iteración 8/100, Mejor valor global: [0.00218403]
# Iteración 9/100, Mejor valor global: [0.00218403]
# Iteración 10/100, Mejor valor global: [0.00218403]
# Iteración 11/100, Mejor valor global: [0.00015976]
# Iteración 12/100, Mejor valor global: [0.00015976]
# Iteración 13/100, Mejor valor global: [5.50530129e-05]
# Iteración 14/100, Mejor valor global: [5.50530129e-05]
# Iteración 15/100, Mejor valor global: [5.04591704e-08]
# Iteración 16/100, Mejor valor global: [5.04591704e-08]
# Iteración 17/100, Mejor valor global: [5.04591704e-08]
# Iteración 18/100, Mejor valor global: [5.04591704e-08]
# Iteración 19/100, Mejor valor global: [5.04591704e-08]
# Iteración 20/100, Mejor valor global: [5.04591704e-08]
# Iteración 21/100, Mejor valor global: [5.04591704e-08]
# Iteración 22/100, Mejor valor global: [5.04591704e-08]
# Iteración 23/100, Mejor valor global: [5.04591704e-08]
# Iteración 24/100, Mejor valor global: [3.03558507e-08]
# Iteración 25/100, Mejor valor global: [3.03558507e-08]
# Iteración 26/100, Mejor valor global: [1.81604065e-09]
# Iteración 27/100, Mejor valor global: [1.81604065e-09]
# Iteración 28/100, Mejor valor global: [1.81604065e-09]
# Iteración 29/100, Mejor valor global: [1.81604065e-09]
# Iteración 30/100, Mejor valor global: [1.81604065e-09]
# Iteración 31/100, Mejor valor global: [1.81604065e-09]
# Iteración 32/100, Mejor valor global: [1.81604065e-09]
# Iteración 33/100, Mejor valor global: [6.28251007e-10]
# Iteración 34/100, Mejor valor global: [6.28251007e-10]
# Iteración 35/100, Mejor valor global: [6.28251007e-10]
# Iteración 36/100, Mejor valor global: [5.13187048e-10]
# Iteración 37/100, Mejor valor global: [5.13187048e-10]
# Iteración 38/100, Mejor valor global: [3.24584803e-12]
# Iteración 39/100, Mejor valor global: [3.24584803e-12]
# Iteración 40/100, Mejor valor global: [3.24584803e-12]
# Iteración 41/100, Mejor valor global: [2.11830553e-13]
# Iteración 42/100, Mejor valor global: [2.11830553e-13]
# Iteración 43/100, Mejor valor global: [2.11830553e-13]
# Iteración 44/100, Mejor valor global: [2.11830553e-13]
# Iteración 45/100, Mejor valor global: [2.11830553e-13]
# Iteración 46/100, Mejor valor global: [3.5971226e-14]
# Iteración 47/100, Mejor valor global: [3.5971226e-14]
# Iteración 48/100, Mejor valor global: [3.5971226e-14]
# Iteración 49/100, Mejor valor global: [3.5971226e-14]
# Iteración 50/100, Mejor valor global: [3.5971226e-14]
# Iteración 51/100, Mejor valor global: [3.21964677e-14]
# Iteración 52/100, Mejor valor global: [3.21964677e-14]
# Iteración 53/100, Mejor valor global: [1.687539e-14]
# Iteración 54/100, Mejor valor global: [1.687539e-14]
# Iteración 55/100, Mejor valor global: [1.687539e-14]
# Iteración 56/100, Mejor valor global: [1.687539e-14]
# Iteración 57/100, Mejor valor global: [1.55431223e-15]
# Iteración 58/100, Mejor valor global: [1.55431223e-15]
# Iteración 59/100, Mejor valor global: [1.55431223e-15]
# Iteración 60/100, Mejor valor global: [6.66133815e-16]
# Iteración 61/100, Mejor valor global: [2.22044605e-16]
# Iteración 62/100, Mejor valor global: [2.22044605e-16]
# Iteración 63/100, Mejor valor global: [0.]
# Iteración 64/100, Mejor valor global: [0.]
# Iteración 65/100, Mejor valor global: [0.]
# Iteración 66/100, Mejor valor global: [0.]
# Iteración 67/100, Mejor valor global: [0.]
# Iteración 68/100, Mejor valor global: [0.]
# Iteración 69/100, Mejor valor global: [0.]
# Iteración 70/100, Mejor valor global: [0.]
# Iteración 71/100, Mejor valor global: [0.]
# Iteración 72/100, Mejor valor global: [0.]
# Iteración 73/100, Mejor valor global: [0.]
# Iteración 74/100, Mejor valor global: [0.]
# Iteración 75/100, Mejor valor global: [0.]
# Iteración 76/100, Mejor valor global: [0.]
# Iteración 77/100, Mejor valor global: [0.]
# Iteración 78/100, Mejor valor global: [0.]
# Iteración 79/100, Mejor valor global: [0.]
# Iteración 80/100, Mejor valor global: [0.]
# Iteración 81/100, Mejor valor global: [0.]
# Iteración 82/100, Mejor valor global: [0.]
# Iteración 83/100, Mejor valor global: [0.]
# Iteración 84/100, Mejor valor global: [0.]
# Iteración 85/100, Mejor valor global: [0.]
# Iteración 86/100, Mejor valor global: [0.]
# Iteración 87/100, Mejor valor global: [0.]
# Iteración 88/100, Mejor valor global: [0.]
# Iteración 89/100, Mejor valor global: [0.]
# Iteración 90/100, Mejor valor global: [0.]
# Iteración 91/100, Mejor valor global: [0.]
# Iteración 92/100, Mejor valor global: [0.]
# Iteración 93/100, Mejor valor global: [0.]
# Iteración 94/100, Mejor valor global: [0.]
# Iteración 95/100, Mejor valor global: [0.]
# Iteración 96/100, Mejor valor global: [0.]
# Iteración 97/100, Mejor valor global: [0.]
# Iteración 98/100, Mejor valor global: [0.]
# Iteración 99/100, Mejor valor global: [0.]
# Iteración 100/100, Mejor valor global: [0.]
# Mejor posición encontrada: [0.63636364], con valor: [0.]

# %% [markdown]
# ## Paso 5. Graficar la Función f(x) = x^2

# %%
# Graficar la función f(x) = x^2
x_values = np.linspace(-10, 10, 400)
y_values = objective_function(x_values)

plt.figure(figsize=(10, 6))
plt.plot(x_values, y_values, label="f(x) = x^2")

# %% [markdown]
# ## Paso 5.1 : Graficar la Función y la mejor posición final

# %%
# Graficar la función f(x) = x^2
x_values = np.linspace(-10, 10, 400)
y_values = objective_function(x_values)


plt.figure(figsize=(10, 6))
plt.plot(x_values, y_values, label="f(x) = x^2")


# Graficar la mejor posición final
plt.scatter([g_best_position], [objective_function(g_best_position)],
            color='blue', marker='x', s=100, label="Mejor posición")

# %% [markdown]
# ## Paso 5.2 : Graficar la Función, la trayectoria de las partículas y la mejor posición final

# %%
# Graficar la función f(x) = x^2
x_values = np.linspace(-10, 10, 400)
y_values = objective_function(x_values)


plt.figure(figsize=(10, 6))
plt.plot(x_values, y_values, label="f(x) = x^2")


# Graficar la trayectoria de las partículas
for positions in history_positions:
    plt.scatter(positions, objective_function(positions), color='red', alpha=0.2)

# Graficar la mejor posición final
plt.scatter([g_best_position], [objective_function(g_best_position)],
            color='blue', marker='x', s=100, label="Mejor posición")

# %% [markdown]
# ## Conclusiones

# %% [markdown]
# ### PSO es un algoritmo de optimización basado en la simulación de la conducta social de organismos, como bandadas de aves o bancos de peces. En esta practica implementamos PSO para buscar el optimo global de una función en 2D y la graficamos: (f(x) = x^2).

# %% [markdown]
# ## Bibliografia

# %% [markdown]
# ### [1] KENNEY, James y EBERHART, Rusell C.. Particle Swarm Optimization. Neural Networks, 1995. Proceedings., IEEE International Conference on vol. 4 p. 1942-1948.
